# %%
# Link Trabalho Final : https://www.dropbox.com/s/3fla2xuc8t9xba2/Deep%20Learning%20-%20Lista%20de%20Exerc%C3%ADcios%20v1.4.pdf?dl=0

# %%
import keras
from keras.datasets import cifar10
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential,load_model
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, AveragePooling2D
from keras.utils import np_utils
#from keras.utils import plot_model
from keras.utils.vis_utils import plot_model
from keras.utils.np_utils import  to_categorical
import tensorflow as tf

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
#!ls -larth '/content/drive/MyDrive/__FIAP/MBA - 17IA/Deep Learning & Reinforcement Learning/dados_trabalho_final/heart.csv'
file_path = 'D:\__Projetos_\_MBA\DeepLearning\deep_learning_final_17ia\dados\heart.csv'

import os.path
if os.path.exists(file_path) :
    print("Arquivo Existe")
# Out:
# Arquivo Existe

# %%
# Importando dados de Heart
import pandas as pd

#heart_csv = pd.read_csv('/content/drive/MyDrive/__FIAP/MBA - 17IA/Deep Learning & Reinforcement Learning/dados_trabalho_final/heart.csv')
heart_csv = pd.read_csv(file_path)

# %%
print("Shape:",heart_csv.shape)
heart_csv.head(5)
# Out:
# Shape: (303, 14)
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_csv.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %%
heart_csv.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
hist = heart_csv.hist(bins=10, figsize=(16,10))

# %%
# Separando dados em X e Y
X= heart_csv.drop('target',axis=1).to_numpy()
Y= heart_csv['target'].to_numpy()
print(X.shape, Y.shape, heart_csv.columns)

from sklearn.model_selection import train_test_split
X_train,X_test,y_train, y_test = train_test_split(X,Y,test_size = 0.3 , random_state = 0 )
# Out:
# (303, 13) (303,) Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
modelo = Sequential()
modelo.add(Dense(activation = "relu", input_dim = 13, 
                     units = 8, kernel_initializer = "uniform"))
modelo.add(Dense(activation = "relu", units = 13, 
                     kernel_initializer = "uniform"))
modelo.add(Dense(activation = "sigmoid", units = 1, 
                     kernel_initializer = "uniform"))
modelo.compile(optimizer = 'adam' , loss = 'binary_crossentropy', 
                   metrics = ['accuracy'] )
modelo.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 8)                 112
# _________________________________________________________________
# dense_1 (Dense)              (None, 13)                117
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 14
# =================================================================
# Total params: 243
# Trainable params: 243
# Non-trainable params: 0
# _________________________________________________________________

# %%
print("Shape X_train:",X_train.shape)
print("Shape X_test:",X_test.shape)
print("Shape y_train:",y_train.shape)
print("Shape y_test:",y_test.shape)
type(X_train)
# Out:
# Shape X_train: (212, 13)
# Shape X_test: (91, 13)
# Shape y_train: (212,)
# Shape y_test: (91,)
# numpy.ndarray

# %%
modelo.fit(X_train , y_train ,epochs = 100)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 0s 709us/step - loss: 0.6929 - accuracy: 0.5283
# Epoch 2/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.6922 - accuracy: 0.5566
# Epoch 3/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.6911 - accuracy: 0.5613
# Epoch 4/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.6895 - accuracy: 0.6226
# Epoch 5/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.6868 - accuracy: 0.7123
# Epoch 6/100
# 7/7 [==============================] - 0s 573us/step - loss: 0.6830 - accuracy: 0.7877
# Epoch 7/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.6774 - accuracy: 0.8113
# Epoch 8/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.6699 - accuracy: 0.8255
# Epoch 9/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.6595 - accuracy: 0.8585
# Epoch 10/100
# 7/7 [==============================] - 0s 427us/step - loss: 0.6457 - accuracy: 0.8538
# Epoch 11/100
# 7/7 [==============================] - 0s 712us/step - loss: 0.6301 - accuracy: 0.8585
# Epoch 12/100
# 7/7 [==============================] - 0s 574us/step - loss: 0.6101 - accuracy: 0.8585
# Epoch 13/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.5889 - accuracy: 0.8585
# Epoch 14/100
# 7/7 [==============================] - 0s 713us/step - loss: 0.5642 - accuracy: 0.8632
# Epoch 15/100
# 7/7 [==============================] - 0s 427us/step - loss: 0.5387 - accuracy: 0.8679
# Epoch 16/100
# 7/7 [==============================] - 0s 428us/step - loss: 0.5135 - accuracy: 0.8726
# Epoch 17/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.4889 - accuracy: 0.8679
# Epoch 18/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.4651 - accuracy: 0.8679
# Epoch 19/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.4444 - accuracy: 0.8726
# Epoch 20/100
# 7/7 [==============================] - 0s 428us/step - loss: 0.4252 - accuracy: 0.8726
# Epoch 21/100
# 7/7 [==============================] - 0s 712us/step - loss: 0.4090 - accuracy: 0.8726
# Epoch 22/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.3944 - accuracy: 0.8726
# Epoch 23/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.3825 - accuracy: 0.8679
# Epoch 24/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.3716 - accuracy: 0.8679
# Epoch 25/100
# 7/7 [==============================] - 0s 427us/step - loss: 0.3628 - accuracy: 0.8726
# Epoch 26/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.3560 - accuracy: 0.8726
# Epoch 27/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.3491 - accuracy: 0.8726
# Epoch 28/100
# 7/7 [==============================] - 0s 855us/step - loss: 0.3443 - accuracy: 0.8774
# Epoch 29/100
# 7/7 [==============================] - 0s 712us/step - loss: 0.3401 - accuracy: 0.8726
# Epoch 30/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.3359 - accuracy: 0.8726
# Epoch 31/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.3331 - accuracy: 0.8726
# Epoch 32/100
# 7/7 [==============================] - 0s 428us/step - loss: 0.3304 - accuracy: 0.8726
# Epoch 33/100
# 7/7 [==============================] - 0s 712us/step - loss: 0.3279 - accuracy: 0.8679
# Epoch 34/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.3259 - accuracy: 0.8726
# Epoch 35/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.3243 - accuracy: 0.8726
# Epoch 36/100
# 7/7 [==============================] - 0s 712us/step - loss: 0.3221 - accuracy: 0.8726
# Epoch 37/100
# 7/7 [==============================] - 0s 712us/step - loss: 0.3208 - accuracy: 0.8679
# Epoch 38/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.3196 - accuracy: 0.8726
# Epoch 39/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.3182 - accuracy: 0.8774
# Epoch 40/100
# 7/7 [==============================] - 0s 428us/step - loss: 0.3172 - accuracy: 0.8774
# Epoch 41/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.3161 - accuracy: 0.8774
# Epoch 42/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.3151 - accuracy: 0.8774
# Epoch 43/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.3143 - accuracy: 0.8821
# Epoch 44/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.3131 - accuracy: 0.8774
# Epoch 45/100
# 7/7 [==============================] - 0s 712us/step - loss: 0.3121 - accuracy: 0.8774
# Epoch 46/100
# 7/7 [==============================] - 0s 712us/step - loss: 0.3112 - accuracy: 0.8774
# Epoch 47/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.3108 - accuracy: 0.8774
# Epoch 48/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.3096 - accuracy: 0.8821
# Epoch 49/100
# 7/7 [==============================] - 0s 427us/step - loss: 0.3088 - accuracy: 0.8821
# Epoch 50/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.3080 - accuracy: 0.8774
# Epoch 51/100
# 7/7 [==============================] - 0s 427us/step - loss: 0.3073 - accuracy: 0.8774
# Epoch 52/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.3068 - accuracy: 0.8821
# Epoch 53/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.3059 - accuracy: 0.8821
# Epoch 54/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.3056 - accuracy: 0.8774
# Epoch 55/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.3045 - accuracy: 0.8774
# Epoch 56/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.3039 - accuracy: 0.8774
# Epoch 57/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.3031 - accuracy: 0.8821
# Epoch 58/100
# 7/7 [==============================] - 0s 428us/step - loss: 0.3022 - accuracy: 0.8821
# Epoch 59/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.3018 - accuracy: 0.8821
# Epoch 60/100
# 7/7 [==============================] - 0s 427us/step - loss: 0.3009 - accuracy: 0.8821
# Epoch 61/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.3006 - accuracy: 0.8868
# Epoch 62/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.2999 - accuracy: 0.8868
# Epoch 63/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.2990 - accuracy: 0.8821
# Epoch 64/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.2984 - accuracy: 0.8821
# Epoch 65/100
# 7/7 [==============================] - 0s 855us/step - loss: 0.2979 - accuracy: 0.8821
# Epoch 66/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.2969 - accuracy: 0.8821
# Epoch 67/100
# 7/7 [==============================] - 0s 427us/step - loss: 0.2965 - accuracy: 0.8821
# Epoch 68/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.2958 - accuracy: 0.8774
# Epoch 69/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.2952 - accuracy: 0.8821
# Epoch 70/100
# 7/7 [==============================] - 0s 427us/step - loss: 0.2941 - accuracy: 0.8868
# Epoch 71/100
# 7/7 [==============================] - 0s 712us/step - loss: 0.2935 - accuracy: 0.8868
# Epoch 72/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.2931 - accuracy: 0.8868
# Epoch 73/100
# 7/7 [==============================] - 0s 997us/step - loss: 0.2923 - accuracy: 0.8868
# Epoch 74/100
# 7/7 [==============================] - 0s 427us/step - loss: 0.2916 - accuracy: 0.8868
# Epoch 75/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.2907 - accuracy: 0.8868
# Epoch 76/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.2902 - accuracy: 0.8868
# Epoch 77/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.2896 - accuracy: 0.8868
# Epoch 78/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.2890 - accuracy: 0.8868
# Epoch 79/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.2883 - accuracy: 0.8868
# Epoch 80/100
# 7/7 [==============================] - 0s 712us/step - loss: 0.2880 - accuracy: 0.8868
# Epoch 81/100
# 7/7 [==============================] - 0s 712us/step - loss: 0.2875 - accuracy: 0.8868
# Epoch 82/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.2868 - accuracy: 0.8868
# Epoch 83/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.2863 - accuracy: 0.8868
# Epoch 84/100
# 7/7 [==============================] - 0s 427us/step - loss: 0.2856 - accuracy: 0.8915
# Epoch 85/100
# 7/7 [==============================] - 0s 427us/step - loss: 0.2852 - accuracy: 0.8915
# Epoch 86/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.2848 - accuracy: 0.8915
# Epoch 87/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.2842 - accuracy: 0.8915
# Epoch 88/100
# 7/7 [==============================] - 0s 712us/step - loss: 0.2834 - accuracy: 0.8915
# Epoch 89/100
# 7/7 [==============================] - 0s 427us/step - loss: 0.2831 - accuracy: 0.8915
# Epoch 90/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.2824 - accuracy: 0.8915
# Epoch 91/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.2820 - accuracy: 0.8915
# Epoch 92/100
# 7/7 [==============================] - 0s 427us/step - loss: 0.2812 - accuracy: 0.8915
# Epoch 93/100
# 7/7 [==============================] - 0s 712us/step - loss: 0.2808 - accuracy: 0.8915
# Epoch 94/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.2803 - accuracy: 0.8915
# Epoch 95/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.2798 - accuracy: 0.8962
# Epoch 96/100
# 7/7 [==============================] - 0s 712us/step - loss: 0.2792 - accuracy: 0.8962
# Epoch 97/100
# 7/7 [==============================] - 0s 427us/step - loss: 0.2793 - accuracy: 0.8962
# Epoch 98/100
# 7/7 [==============================] - 0s 427us/step - loss: 0.2786 - accuracy: 0.8962
# Epoch 99/100
# 7/7 [==============================] - 0s 712us/step - loss: 0.2780 - accuracy: 0.8962
# Epoch 100/100
# 7/7 [==============================] - 0s 570us/step - loss: 0.2773 - accuracy: 0.8962

# %%
scores = modelo.evaluate(X_test, y_test)
print("\n%s: %.2f%%" % (modelo.metrics_names[1], scores[1]*100))
# Out:
# 3/3 [==============================] - 0s 665us/step - loss: 0.4277 - accuracy: 0.8352
#
# accuracy: 83.52%

# %%
scores = modelo.evaluate(X_train, y_train)
print("\n%s: %.2f%%" % (modelo.metrics_names[1], scores[1]*100))
# Out:
# 7/7 [==============================] - 0s 427us/step - loss: 0.2764 - accuracy: 0.8962
#
# accuracy: 89.62%
